# %% [markdown]
# <a href="https://colab.research.google.com/github/KaeideN/Chess-AI-Project/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='/content/drive/MyDrive/datasetChess/train/images/20250125_014313_jpg.rf.761f52dceab9e5e78aa50e5f47b8f1a1.jpg'
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 241MB/s]
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43,668,288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/1 /content/drive/MyDrive/datasetChess/train/images/20250125_014313_jpg.rf.761f52dceab9e5e78aa50e5f47b8f1a1.jpg: 640x640 1 vase, 62.9ms
# Speed: 5.9ms preprocess, 62.9ms inference, 733.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # **Custom Data Training**

# %%
# !yolo task=detect mode=train model=yolov8l.pt conf=0.25 data='/content/drive/MyDrive/datasetChess/data.yaml' epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
